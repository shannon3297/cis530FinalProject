# %% [markdown]
# This code tracks sentiment over time of users with top retweeted Tweets from the training dataset. To run this code, click play on every cell from top to bottom, enjoy!

# %% [markdown]
# # Vaccine specific tweets

# %%
# imports
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
pd.set_option('max_colwidth', 400)
# Out:
# Mounted at /content/drive

# %%
train_file = input("What's the path to your vaccine train.csv dataset? Ex: /content/drive/MyDrive/CIS530/CIS530 Final Project/Milestone 4/train-dev-test/train_vax_cleaned.csv: ")
dev_file = input("What's the path to your vaccine dev.csv dataset? Ex: /content/drive/MyDrive/CIS530/CIS530 Final Project/Milestone 4/train-dev-test/dev_vax_cleaned.csv: ")
test_file = input("What's the path to your vaccine test.csv dataset? Ex: /content/drive/MyDrive/CIS530/CIS530 Final Project/Milestone 4/train-dev-test/test_vax_cleaned.csv: ")
train_df = pd.read_csv(train_file, low_memory=False, encoding='utf-8-sig')
dev_df = pd.read_csv(dev_file, low_memory=False, encoding='utf-8-sig')
test_df = pd.read_csv(test_file, low_memory=False, encoding='utf-8-sig')
# Out:
# What's the path to your vaccine train.csv dataset? Ex: /content/drive/MyDrive/CIS530/CIS530 Final Project/Milestone 4/train-dev-test/train_vax_cleaned.csv: /content/drive/MyDrive/CIS530/CIS530 Final Project/Milestone 4/train-dev-test/train_vax_cleaned.csv
# What's the path to your vaccine dev.csv dataset? Ex: /content/drive/MyDrive/CIS530/CIS530 Final Project/Milestone 4/train-dev-test/dev_vax_cleaned.csv: /content/drive/MyDrive/CIS530/CIS530 Final Project/Milestone 4/train-dev-test/dev_vax_cleaned.csv
# What's the path to your vaccine test.csv dataset? Ex: /content/drive/MyDrive/CIS530/CIS530 Final Project/Milestone 4/train-dev-test/test_vax_cleaned.csv: /content/drive/MyDrive/CIS530/CIS530 Final Project/Milestone 4/train-dev-test/test_vax_cleaned.csv

# %%
# drop duplicates and retweets
def cleanData(df):
  cleaned = df.drop_duplicates('text', keep='last')
  cleaned = cleaned[~cleaned.text.str.contains("RT @")]
  print(cleaned.columns)
  return cleaned

# %%
# get top 20 tweets overall and sentiment distribution/top 20 tweets/top 20 tweet sentiment distribution in each month and year
def getAnalysis(inputted_df):
  top_20_vax_df = inputted_df.nlargest(20, 'retweet_count')
  print("Sentiment distribution of top 20 Tweets from March 2020 to April 2021")
  print(top_20_vax_df['sentiment'].value_counts())
  months = ['Jan', 'Feb', 'Mar', 'Apr', 'May',' Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
  years = [2020, 2021]
  for yr in years:
    for mo in months:
      print("analytics for", mo, yr)
      df = inputted_df[(inputted_df['month'] == mo) & (inputted_df['year'] == yr)]
      print("Sentiment distribution of all tweets in given mo and yr")
      print(df['sentiment'].value_counts())
      top_20_mo_yr = df.nlargest(20, 'retweet_count')
      print("Sentiment distribution of top 20")
      print(top_20_mo_yr['sentiment'].value_counts())
      top = df.nlargest(1, 'retweet_count')
      print("Top tweeted: ", top['text'], "with", top['retweet_count'], "tweets and occured on", top['month'], top['day'], top['year'])

# %%
# get analysis of vaccine specific tweets
noretweets_train_df = cleanData(train_df)
getAnalysis(noretweets_train_df)
# Out:
# Index(['Unnamed: 0', 'text', 'place', 'user_location', 'followers_count',
#        'retweet_count', 'favorite_count', 'hashtags', 'weekday', 'month',
#        'day', 'time', 'year', 'num_present', 'trump_present',
#        'hashtag_present', 'covid', 'vaccine', 'profanity_present',
#        'emoji_present', 'url_present', 'question_exclamation_present',
#        'sentiment'],
#       dtype='object')
# Sentiment distribution of top 20 Tweets from March 2020 to April 2021
# positive    12
# negative     6
# neutral      2
# Name: sentiment, dtype: int64
# analytics for Jan 2020
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Feb 2020
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Mar 2020
# Sentiment distribution of all tweets in given mo and yr
# neutral     39
# positive    33
# negative    22
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# neutral     9
# positive    8
# negative    3
# Name: sentiment, dtype: int64
# Top tweeted:  178040    Somebody send my mother a video here with a pastor telling he flock (deliberate word usage) not to take any vaccine cuz it has the corona virus in it. \n\nMy mother know better but I know this kinda shite getting through to people. \n\nStupidity is the real virus.
# Name: text, dtype: object with 178040    3
# Name: retweet_count, dtype: int64 tweets and occured on 178040    Mar
# Name: month, dtype: object 178040    19.0
# Name: day, dtype: float64 178040    2020.0
# Name: year, dtype: float64
# analytics for Apr 2020
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for May 2020
# Sentiment distribution of all tweets in given mo and yr
# positive    20
# neutral      9
# negative     9
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# positive    10
# negative     6
# neutral      4
# Name: sentiment, dtype: int64
# Top tweeted:  178234    BREAKING: WHO wanted to bribe Madagascarn President to poison #COVID19 medicine.😲 #BillGates vaccine suspended by FDA in the USA. #lockdown #BarackObama #Eurovision #LockDownKenya #mariaoncitizen #KabugaArrested Luba kibaki #Milelegospelsunday #RicHassani #LudacrisvsNelly https://t.co/WWWGl4776h
# Name: text, dtype: object with 178234    6
# Name: retweet_count, dtype: int64 tweets and occured on 178234    May
# Name: month, dtype: object 178234    17.0
# Name: day, dtype: float64 178234    2020.0
# Name: year, dtype: float64
# analytics for  Jun 2020
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Jul 2020
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Aug 2020
# Sentiment distribution of all tweets in given mo and yr
# positive    58
# neutral     48
# negative    18
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# neutral     9
# positive    6
# negative    5
# Name: sentiment, dtype: int64
# Top tweeted:  190496    Russia says it has orders for 1 billion doses of coronavirus vaccine Sputnik V https://t.co/20yP4HMYUa
# Name: text, dtype: object with 190496    38
# Name: retweet_count, dtype: int64 tweets and occured on 190496    Aug
# Name: month, dtype: object 190496    12.0
# Name: day, dtype: float64 190496    2020.0
# Name: year, dtype: float64
# analytics for Sep 2020
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Oct 2020
# Sentiment distribution of all tweets in given mo and yr
# positive    25
# negative    16
# neutral     11
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# positive    10
# negative     7
# neutral      3
# Name: sentiment, dtype: int64
# Top tweeted:  190584    Anyone hear calls like this in #Texas?\n"Wohl and Burkman attempt to trick listeners into not sending in mail-in ballots, falsely warning that the information would be used to track fugitives, collect on credit card debts, and enforce “mandatory vaccines"\nhttps://t.co/4fxkWARyTS
# Name: text, dtype: object with 190584    6
# Name: retweet_count, dtype: int64 tweets and occured on 190584    Oct
# Name: month, dtype: object 190584    2.0
# Name: day, dtype: float64 190584    2020.0
# Name: year, dtype: float64
# analytics for Nov 2020
# Sentiment distribution of all tweets in given mo and yr
# neutral     33
# positive    27
# negative    16
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# neutral     12
# positive     6
# negative     2
# Name: sentiment, dtype: int64
# Top tweeted:  190692    The Health Ministry says the use of 2 influenza vaccine products can continue, following the conclusion of an investigation.\n\nVaxigrip Tetra and SKYCellflu Quadrivalent were temporarily discontinued, after being linked to deaths in South Korea. https://t.co/MD6EAZkXbM
# Name: text, dtype: object with 190692    8
# Name: retweet_count, dtype: int64 tweets and occured on 190692    Nov
# Name: month, dtype: object 190692    3.0
# Name: day, dtype: float64 190692    2020.0
# Name: year, dtype: float64
# analytics for Dec 2020
# Sentiment distribution of all tweets in given mo and yr
# positive    703
# neutral     520
# negative    366
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# positive    12
# neutral      5
# negative     3
# Name: sentiment, dtype: int64
# Top tweeted:  179229    South Africa missed the first payment window to ensure participation in a global vaccine access programme, COVAX, amid confusion, contradiction and silence from the government on its efforts to secure doses. | @CowansView \nhttps://t.co/wEKhoUuZjA
# Name: text, dtype: object with 179229    595
# Name: retweet_count, dtype: int64 tweets and occured on 179229    Dec
# Name: month, dtype: object 179229    3.0
# Name: day, dtype: float64 179229    2020.0
# Name: year, dtype: float64
# analytics for Jan 2021
# Sentiment distribution of all tweets in given mo and yr
# positive    544
# neutral     342
# negative    224
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# positive    9
# neutral     6
# negative    5
# Name: sentiment, dtype: int64
# Top tweeted:  192176    Bill Gates needs to do an interview with a robust journalist clarifying some of his earlier comments about vaccines and population control.\n\nThat will go a long way in restoring the trust. Some concerns that people have stem directly from things that he said.\n\nIt’s hard to ignore
# Name: text, dtype: object with 192176    271
# Name: retweet_count, dtype: int64 tweets and occured on 192176    Jan
# Name: month, dtype: object 192176    12.0
# Name: day, dtype: float64 192176    2021.0
# Name: year, dtype: float64
# analytics for Feb 2021
# Sentiment distribution of all tweets in given mo and yr
# positive    212
# neutral     155
# negative    110
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# positive    8
# negative    7
# neutral     5
# Name: sentiment, dtype: int64
# Top tweeted:  182405    Oxfam has made some disappointing errors in a press release various tweeps are relying upon. Oxfam claims that Canada has *purchased* vaccines to inoculate the population three times over. There is a difference between purchasing and receiving, as we have discovered. /2 #cdnpoli
# Name: text, dtype: object with 182405    39
# Name: retweet_count, dtype: int64 tweets and occured on 182405    Feb
# Name: month, dtype: object 182405    5.0
# Name: day, dtype: float64 182405    2021.0
# Name: year, dtype: float64
# analytics for Mar 2021
# Sentiment distribution of all tweets in given mo and yr
# positive    242
# neutral     147
# negative    125
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# positive    12
# neutral      5
# negative     3
# Name: sentiment, dtype: int64
# Top tweeted:  183580    25) A lot of people still don’t understand mRNA vaccines like Pfizer and Moderna. So here is a more simple explainer. https://t.co/0LuL020Qjo
# Name: text, dtype: object with 183580    321
# Name: retweet_count, dtype: int64 tweets and occured on 183580    Mar
# Name: month, dtype: object 183580    15.0
# Name: day, dtype: float64 183580    2021.0
# Name: year, dtype: float64
# analytics for Apr 2021
# Sentiment distribution of all tweets in given mo and yr
# positive    833
# neutral     570
# negative    400
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# positive    8
# negative    7
# neutral     5
# Name: sentiment, dtype: int64
# Top tweeted:  188694    Vaccine Karens are the same as the mask Karens - they don't actually care about other people's health, it just makes them feel superior to yell at people who choose not to comply.
# Name: text, dtype: object with 188694    236
# Name: retweet_count, dtype: int64 tweets and occured on 188694    Apr
# Name: month, dtype: object 188694    2.0
# Name: day, dtype: float64 188694    2021.0
# Name: year, dtype: float64
# analytics for May 2021
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for  Jun 2021
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Jul 2021
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Aug 2021
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Sep 2021
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Oct 2021
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Nov 2021
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Dec 2021
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)

# %% [markdown]
# # All coronavirus-related Tweets

# %%
generic_train_file = input("What's the path to your train.csv dataset? Ex: /content/drive/MyDrive/CIS530/CIS530 Final Project/Milestone 4/train-dev-test/train_cleaned.csv: ")
generic_dev_file = input("What's the path to your dev.csv dataset? Ex: /content/drive/MyDrive/CIS530/CIS530 Final Project/Milestone 4/train-dev-test/dev_cleaned.csv: ")
generic_test_file = input("What's the path to your test.csv dataset? Ex: /content/drive/MyDrive/CIS530/CIS530 Final Project/Milestone 4/train-dev-test/test_cleaned.csv: ")
generic_train_df = pd.read_csv(generic_train_file, low_memory=False, encoding='utf-8-sig')
generic_dev_df = pd.read_csv(generic_dev_file, low_memory=False, encoding='utf-8-sig')
generic_test_df = pd.read_csv(generic_test_file, low_memory=False, encoding='utf-8-sig')
# Out:
# What's the path to your train.csv dataset? Ex: /content/drive/MyDrive/CIS530/CIS530 Final Project/Milestone 4/train-dev-test/train_cleaned.csv: /content/drive/MyDrive/CIS530/CIS530 Final Project/Milestone 4/train-dev-test/train_cleaned.csv
# What's the path to your dev.csv dataset? Ex: /content/drive/MyDrive/CIS530/CIS530 Final Project/Milestone 4/train-dev-test/dev_cleaned.csv: /content/drive/MyDrive/CIS530/CIS530 Final Project/Milestone 4/train-dev-test/dev_cleaned.csv
# What's the path to your test.csv dataset? Ex: /content/drive/MyDrive/CIS530/CIS530 Final Project/Milestone 4/train-dev-test/test_cleaned.csv: /content/drive/MyDrive/CIS530/CIS530 Final Project/Milestone 4/train-dev-test/test_cleaned.csv

# %%
# get analysis of all corona-related tweets
noretweets_generic_train_df = cleanData(generic_dev_df)
noretweets_generic_train_df = noretweets_generic_train_df[~noretweets_generic_train_df.retweet_count.str.contains("retweet_count")]
noretweets_generic_train_df["retweet_count"] = pd.to_numeric(noretweets_generic_train_df['retweet_count'])
getAnalysis(noretweets_generic_train_df)
# Out:
# Index(['text', 'place', 'user_location', 'followers_count', 'retweet_count',
#        'favorite_count', 'hashtags', 'weekday', 'month', 'day', 'time', 'year',
#        'num_present', 'trump_present', 'hashtag_present', 'covid', 'vaccine',
#        'profanity_present', 'emoji_present', 'url_present',
#        'question_exclamation_present', 'sentiment'],
#       dtype='object')
# 412185    0
# 412195    0
# 412202    1
# 412203    0
# 412205    0
#          ..
# 439311    0
# 439317    0
# 439320    0
# 439323    0
# 439325    0
# Name: retweet_count, Length: 7409, dtype: int64
#                                                                                                                                                                                                                                                                                                        text  ... sentiment
# 412185                                                             if I caugh don't ask if I got the corona virus bitch its spring I got mf allergies an was outside no swaeter cold mfs really trippin but forgot when Obama was president h1n1 killed 18k people an 500 mil was infected yall needa chill  ...  negative
# 412195                                                                                                                                                                                            @Banks  bro the first guy has got to be you lmao. No way that voice isn’t yours 😂 https://t.co/XHLZizkptn  ...  positive
# 412202                                                      Panic buying kills people -the more you jam into supermarkets queuing up grabbing stuff off shelves the more the virus spreads and somewhere someones mother or father dies of corona virus for that tin of beans- well done you fucking idiots  ...  positive
# 412203                                                                                                                                                                                       Just heard the company moderna has a fighting cure against the corona virus. Go get the vaccine shot. #covid19  ...   neutral
# 412205                                                                                                                                                                                                      Diane Abbotts thoughts on Corona, its nice cold with a slice lime but the bubbles make me burp!  ...  negative
# 412206                                                                                                                                                                                                           I literally hope God comes down to smite this motherfucker himself https://t.co/VpfAE2fYyB  ...  negative
# 412210  @sumrag @CMOMaharashtra @mybmc @AUThackeray Sumeet your message is genuine and so true but it’s should reach each household . Not all people have twitter account , People should be hammered constantly by asking them to stay at home and how we all should fight together against corona .Thanks  ...  positive
# 412215                                                                                                                                                                                                                                                       Corona day ???: I have no idea what day it is.  ...   neutral
# 412220                                                                                                                                                                                                                         @TheEllenShow How true is that u r not inviting Corona on ur show\n#AskEllen  ...  positive
# 412224                                                                                                                                                        He had trouble reading that big print. WTF America?\n\n#25thAmendmentNow #TrumpPandemic #TrumpIsTheWORSTPresidentEVER https://t.co/pt186NCWkW  ...  negative
#
# [10 rows x 22 columns]
# Sentiment distribution of top 20 Tweets from March 2020 to April 2021
# positive    9
# neutral     7
# negative    4
# Name: sentiment, dtype: int64
# analytics for Jan 2020
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Feb 2020
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Mar 2020
# Sentiment distribution of all tweets in given mo and yr
# neutral     1051
# positive     915
# negative     677
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# positive    9
# negative    6
# neutral     5
# Name: sentiment, dtype: int64
# Top tweeted:  416451    As a doctor my self and as  wife of a doctor who is working with Corona Virus patients, let me assure you that we don’t want people clapping for us, what we really need is more testing kits, better quarantine facilities, hazmat suits, more awareness and I mean correct awareness
# Name: text, dtype: object with 416451    6617
# Name: retweet_count, dtype: int64 tweets and occured on 416451    Mar
# Name: month, dtype: object 416451    19.0
# Name: day, dtype: float64 416451    2020.0
# Name: year, dtype: float64
# analytics for Apr 2020
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for May 2020
# Sentiment distribution of all tweets in given mo and yr
# positive    87
# neutral     74
# negative    47
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# positive    9
# neutral     6
# negative    5
# Name: sentiment, dtype: int64
# Top tweeted:  422910    How can a normal human being with good heart be shifting thausands of terrorists from #CoronaVirus infected states &amp; region (Northern Nigeria) down to the  uninfected Holy land of #Biafra?, During pandemic lockdown? \n#WeSayNoToAlmajiri\n@SecPompeo\nHold @elrufai responsible! https://t.co/WVtWj4UscV
# Name: text, dtype: object with 422910    143
# Name: retweet_count, dtype: int64 tweets and occured on 422910    May
# Name: month, dtype: object 422910    17.0
# Name: day, dtype: float64 422910    2020.0
# Name: year, dtype: float64
# analytics for  Jun 2020
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Jul 2020
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Aug 2020
# Sentiment distribution of all tweets in given mo and yr
# positive    143
# neutral      79
# negative     55
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# positive    11
# neutral      6
# negative     3
# Name: sentiment, dtype: int64
# Top tweeted:  433676    California Will Soon Be Paying $1,250 To People Who Test Positive For Coronavirus https://t.co/mpDi7WuCv3
# Name: text, dtype: object with 433676    187
# Name: retweet_count, dtype: int64 tweets and occured on 433676    Aug
# Name: month, dtype: object 433676    12.0
# Name: day, dtype: float64 433676    2020.0
# Name: year, dtype: float64
# analytics for Sep 2020
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Oct 2020
# Sentiment distribution of all tweets in given mo and yr
# positive    127
# neutral     112
# negative     91
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# positive    9
# neutral     8
# negative    3
# Name: sentiment, dtype: int64
# Top tweeted:  429911    People are saying we want Trump to die or we are mocking that he has COVID.\n\nWrong. \n\nWe are not surprised that he has COVID. He subjected himself and others to risk factors on a daily basis.\n\nDie? \n\nNo. We want him to live and face indictments, humiliation and prison.
# Name: text, dtype: object with 429911    1157
# Name: retweet_count, dtype: int64 tweets and occured on 429911    Oct
# Name: month, dtype: object 429911    4.0
# Name: day, dtype: float64 429911    2020.0
# Name: year, dtype: float64
# analytics for Nov 2020
# Sentiment distribution of all tweets in given mo and yr
# positive    118
# neutral      75
# negative     73
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# neutral     7
# positive    7
# negative    6
# Name: sentiment, dtype: int64
# Top tweeted:  435667    #MarkUrquiza can’t vote and neither can 230,000+ other lives cut short by #COVID. Your voice matters not just for you but for them. #Elections2020 #BidenHarris2020 #BidenHarrisToSaveAmerica #2020Elections #VOTE #DiaDeMuertos #AllSaintsDay2020 #AllSoulsDay #MarkedByCOVID https://t.co/VuAogOTjGd
# Name: text, dtype: object with 435667    34
# Name: retweet_count, dtype: int64 tweets and occured on 435667    Nov
# Name: month, dtype: object 435667    3.0
# Name: day, dtype: float64 435667    2020.0
# Name: year, dtype: float64
# analytics for Dec 2020
# Sentiment distribution of all tweets in given mo and yr
# positive    477
# neutral     393
# negative    281
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# positive    8
# negative    6
# neutral     6
# Name: sentiment, dtype: int64
# Top tweeted:  436021    More misleading reporting from CBS. There are 547 people -STATEWIDE- in the hospital in South Dakota w COVID. That’s less than 20% of those hospitalized. Nearly 40% of our beds are empty. Our doctors &amp; nurses are doing an OUTSTANDING job taking care of those who need extra care. https://t.co/GU85Znjuk4 https://t.co/RYfM0c4nGB
# Name: text, dtype: object with 436021    3746
# Name: retweet_count, dtype: int64 tweets and occured on 436021    Dec
# Name: month, dtype: object 436021    2.0
# Name: day, dtype: float64 436021    2020.0
# Name: year, dtype: float64
# analytics for Jan 2021
# Sentiment distribution of all tweets in given mo and yr
# positive    371
# neutral     260
# negative    208
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# positive    11
# neutral      6
# negative     3
# Name: sentiment, dtype: int64
# Top tweeted:  425110    Belarusian president has revealed that the IMF &amp; World Bank tried to bribe him with $940m to impose a complete lockdown/police state, enforce masks and crash his nation’s economy. Lukashenko refused. Is the agenda really a mystery? Where's the media?\nhttps://t.co/VbiiPugs27
# Name: text, dtype: object with 425110    77
# Name: retweet_count, dtype: int64 tweets and occured on 425110    Jan
# Name: month, dtype: object 425110    14.0
# Name: day, dtype: float64 425110    2021.0
# Name: year, dtype: float64
# analytics for Feb 2021
# Sentiment distribution of all tweets in given mo and yr
# positive    127
# neutral      89
# negative     55
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# positive    11
# negative     6
# neutral      3
# Name: sentiment, dtype: int64
# Top tweeted:  426536    #Mumbai\nNeed #Blood Type :  A-positive\nAt : Nanavati Hospital, Vile Parle\nBlood Component : Need Plasma from A+ve/A-ve #COVID19 recovered patient.\nNumber of Units : 2\nPrimary Number : 9004787195\nVia: @Royal__bhumihar\n#BloodMatters\nPowered by Twitter https://t.co/GGMcIVbCeh
# Name: text, dtype: object with 426536    49
# Name: retweet_count, dtype: int64 tweets and occured on 426536    Feb
# Name: month, dtype: object 426536    5.0
# Name: day, dtype: float64 426536    2021.0
# Name: year, dtype: float64
# analytics for Mar 2021
# Sentiment distribution of all tweets in given mo and yr
# positive    168
# neutral     114
# negative     66
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# neutral     9
# positive    8
# negative    3
# Name: sentiment, dtype: int64
# Top tweeted:  426649    My fellow Christians; if scientists tell us wearing a mask saves your life &amp; the lives of others, it is not tyranny to wear one or a loss of freedom. But knowingly going maskless in the face of science is suicide. It is murder. Both are sins. Wear a mask.
# Name: text, dtype: object with 426649    99
# Name: retweet_count, dtype: int64 tweets and occured on 426649    Mar
# Name: month, dtype: object 426649    15.0
# Name: day, dtype: float64 426649    2021.0
# Name: year, dtype: float64
# analytics for Apr 2021
# Sentiment distribution of all tweets in given mo and yr
# positive    418
# neutral     294
# negative    201
# Name: sentiment, dtype: int64
# Sentiment distribution of top 20
# positive    11
# negative     5
# neutral      4
# Name: sentiment, dtype: int64
# Top tweeted:  433099    B+ Blood is required who has been recovered from Corona\n\nPlease help our friend @ActivatePTI need it.. \n\nPlease come forward
# Name: text, dtype: object with 433099    124
# Name: retweet_count, dtype: int64 tweets and occured on 433099    Apr
# Name: month, dtype: object 433099    2.0
# Name: day, dtype: float64 433099    2021.0
# Name: year, dtype: float64
# analytics for May 2021
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for  Jun 2021
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Jul 2021
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Aug 2021
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Sep 2021
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Oct 2021
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Nov 2021
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)
# analytics for Dec 2021
# Sentiment distribution of all tweets in given mo and yr
# Series([], Name: sentiment, dtype: int64)
# Sentiment distribution of top 20
# Series([], Name: sentiment, dtype: int64)
# Top tweeted:  Series([], Name: text, dtype: object) with Series([], Name: retweet_count, dtype: int64) tweets and occured on Series([], Name: month, dtype: object) Series([], Name: day, dtype: float64) Series([], Name: year, dtype: float64)

# %%
# important event date: Olympic games postponed on 3/30/2020
olympic_df = noretweets_train_df[(noretweets_train_df['month'] == 'Mar') & (noretweets_train_df['day'] == 30) & (noretweets_train_df['year'] == '2020')]
print("distribution of all sentiments:")
print(olympic_df['sentiment'].value_counts())
top20 = olympic_df.nlargest(20, 'retweet_count')
print("distribution of top 20 sentiments:")
print(olympic_df['sentiment'].value_counts())
# Out:
# distribution of all sentiments:
# Series([], Name: sentiment, dtype: int64)
# distribution of top 20 sentiments:
# Series([], Name: sentiment, dtype: int64)

# %%
trump_covid_df = noretweets_train_df[(noretweets_train_df['month'] == 'Oct') & (noretweets_train_df['day'] == 2) & (noretweets_train_df['year'] == '2020')]
